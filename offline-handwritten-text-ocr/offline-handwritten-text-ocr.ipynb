# %% [markdown]
# # *Offline Handwritten Text Recognition (using Python 3.10.4)*
#
# ### The purpose of this notebook is to give a brief idea and a basic approach for offline handwritten text recognition by using segmentation and classification.

# %% [markdown]
# ## What is Offline Handwritten Text Recognition?
# Offline handwriting recognition involves the automatic conversion of text in an image into letter codes that are usable within computer and text-processing applications. In simple terms, it is the text extraction from your handwritten notebooks/pages. Why called offline? The point being that there is an online text recognition system, which is referred for text that is digitally generated by using tools like stylus, apple pencil, etc.

# %% [markdown]
# ## Approach
#
# * **Step1** :  Build a digit(0-9) + A-Z characters classifier using a CNN architecture.
# * **Step2** :  Apply character segmentation for the handwritten word image.
# * **Step3** :  Classify each segmented letter and then get the final word in the image.

# %%
# !pip install imutils
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py) ... done
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25836 sha256=27dfc81f9023340a237f70017d16dff37c052e65afa77589925eff3ebb5179f1
#   Stored in directory: /home/dung/.cache/pip/wheels/85/cf/3a/e265e975a1e7c7e54eb3692d6aa4e2e7d6a3945d29da46f2d7
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4

# %%
import numpy as np
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator
import os
import random 
import cv2
import imutils
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelBinarizer
from keras.utils import np_utils
from keras.models import Sequential
from keras import optimizers
from sklearn.preprocessing import LabelBinarizer
from keras import backend as K
from keras.layers import Dense, Activation, Flatten, Dense,MaxPooling2D, Dropout
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
# Out:
# 2022-08-02 16:34:17.989567: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-08-02 16:34:18.053412: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-02 16:34:18.053430: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
dir = "/home/dung/Desktop/offline-handwritten-text-ocr/archive/Train/"
train_data = []
img_size = 32
non_chars = ["#","$","&","@"]
for i in os.listdir(dir):
    if i in non_chars:
        continue
    count = 0
    sub_directory = os.path.join(dir,i)
    for j in os.listdir(sub_directory):
        count+=1
        if count > 4000:
            break
        img = cv2.imread(os.path.join(sub_directory,j),0)
        img = cv2.resize(img,(img_size,img_size))
        train_data.append([img,i])

# %%
len(train_data)
# Out:
# 140000

# %%
val_dir = "/home/dung/Desktop/offline-handwritten-text-ocr/archive/Validation/"
val_data = []
img_size = 32
for i in os.listdir(val_dir):
    if i in non_chars:
        continue
    count = 0
    sub_directory = os.path.join(val_dir,i)
    for j in os.listdir(sub_directory):
        count+=1
        if count > 1000:
            break
        img = cv2.imread(os.path.join(sub_directory,j),0)
        img = cv2.resize(img,(img_size,img_size))
        val_data.append([img,i])

# %%
len(val_data)
# Out:
# 15209

# %%
random.shuffle(train_data)
random.shuffle(val_data)

# %%
train_X = []
train_Y = []
for features,label in train_data:
    train_X.append(features)
    train_Y.append(label)

# %%
val_X = []
val_Y = []
for features,label in val_data:
    val_X.append(features)
    val_Y.append(label)

# %%
LB = LabelBinarizer()
train_Y = LB.fit_transform(train_Y)
val_Y = LB.fit_transform(val_Y)

# %%
train_X = np.array(train_X)/255.0
train_X = train_X.reshape(-1,32,32,1)
train_Y = np.array(train_Y)

# %%
val_X = np.array(val_X)/255.0
val_X = val_X.reshape(-1,32,32,1)
val_Y = np.array(val_Y)

# %%
print(train_X.shape,val_X.shape)
# Out:
# (140000, 32, 32, 1) (15209, 32, 32, 1)

# %%
print(train_Y.shape,val_Y.shape)
# Out:
# (140000, 35) (15209, 35)

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), padding = "same", activation='relu', input_shape=(32,32,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
 
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(35, activation='softmax'))
# Out:
# 2022-08-02 16:35:55.947800: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/dung/.local/lib/python3.10/site-packages/cv2/../../lib64:
# 2022-08-02 16:35:55.948171: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-08-02 16:35:55.949084: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (inspirion3511): /proc/driver/nvidia/version does not exist
# 2022-08-02 16:35:55.954522: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 5, 5, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  dropout (Dropout)           (None, 2, 2, 128)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 35)                4515
#
# =================================================================
# Total params: 162,851
# Trainable params: 162,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer="adam",metrics=['accuracy'])

# %%
history = model.fit(train_X,train_Y, epochs=100, batch_size=32, validation_data = (val_X, val_Y),  verbose=1)
# Out:
# Epoch 1/100
# 4375/4375 [==============================] - 50s 11ms/step - loss: 0.6195 - accuracy: 0.8020 - val_loss: 0.3089 - val_accuracy: 0.9046
# Epoch 2/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.3498 - accuracy: 0.8820 - val_loss: 0.3010 - val_accuracy: 0.9012
# Epoch 3/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.3033 - accuracy: 0.8970 - val_loss: 0.2634 - val_accuracy: 0.9060
# Epoch 4/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.2806 - accuracy: 0.9023 - val_loss: 0.2466 - val_accuracy: 0.9129
# Epoch 5/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.2639 - accuracy: 0.9081 - val_loss: 0.2426 - val_accuracy: 0.9144
# Epoch 6/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.2505 - accuracy: 0.9122 - val_loss: 0.2199 - val_accuracy: 0.9275
# Epoch 7/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.2406 - accuracy: 0.9152 - val_loss: 0.2539 - val_accuracy: 0.9059
# Epoch 8/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.2324 - accuracy: 0.9180 - val_loss: 0.2446 - val_accuracy: 0.9159
# Epoch 9/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.2250 - accuracy: 0.9194 - val_loss: 0.2144 - val_accuracy: 0.9264
# Epoch 10/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.2194 - accuracy: 0.9211 - val_loss: 0.2333 - val_accuracy: 0.9219
# Epoch 11/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.2142 - accuracy: 0.9226 - val_loss: 0.2283 - val_accuracy: 0.9234
# Epoch 12/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.2100 - accuracy: 0.9243 - val_loss: 0.2334 - val_accuracy: 0.9162
# Epoch 13/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.2050 - accuracy: 0.9256 - val_loss: 0.2269 - val_accuracy: 0.9271
# Epoch 14/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.2013 - accuracy: 0.9272 - val_loss: 0.2481 - val_accuracy: 0.9085
# Epoch 15/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.2004 - accuracy: 0.9270 - val_loss: 0.2391 - val_accuracy: 0.9172
# Epoch 16/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1968 - accuracy: 0.9285 - val_loss: 0.2227 - val_accuracy: 0.9269
# Epoch 17/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1924 - accuracy: 0.9294 - val_loss: 0.2189 - val_accuracy: 0.9289
# Epoch 18/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1907 - accuracy: 0.9301 - val_loss: 0.2457 - val_accuracy: 0.9120
# Epoch 19/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1897 - accuracy: 0.9301 - val_loss: 0.2417 - val_accuracy: 0.9162
# Epoch 20/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1883 - accuracy: 0.9311 - val_loss: 0.2455 - val_accuracy: 0.9145
# Epoch 21/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1835 - accuracy: 0.9324 - val_loss: 0.2447 - val_accuracy: 0.9184
# Epoch 22/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1831 - accuracy: 0.9317 - val_loss: 0.2505 - val_accuracy: 0.9175
# Epoch 23/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1835 - accuracy: 0.9318 - val_loss: 0.2414 - val_accuracy: 0.9202
# Epoch 24/100
# 4375/4375 [==============================] - 42s 10ms/step - loss: 0.1808 - accuracy: 0.9328 - val_loss: 0.2480 - val_accuracy: 0.9155
# Epoch 25/100
# 4375/4375 [==============================] - 48s 11ms/step - loss: 0.1807 - accuracy: 0.9327 - val_loss: 0.2375 - val_accuracy: 0.9245
# Epoch 26/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1796 - accuracy: 0.9331 - val_loss: 0.2358 - val_accuracy: 0.9256
# Epoch 27/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1772 - accuracy: 0.9333 - val_loss: 0.2468 - val_accuracy: 0.9143
# Epoch 28/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1761 - accuracy: 0.9338 - val_loss: 0.2452 - val_accuracy: 0.9214
# Epoch 29/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1766 - accuracy: 0.9341 - val_loss: 0.2509 - val_accuracy: 0.9217
# Epoch 30/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.1749 - accuracy: 0.9347 - val_loss: 0.2416 - val_accuracy: 0.9212
# Epoch 31/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1733 - accuracy: 0.9358 - val_loss: 0.2466 - val_accuracy: 0.9252
# Epoch 32/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.1731 - accuracy: 0.9358 - val_loss: 0.2528 - val_accuracy: 0.9214
# Epoch 33/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1725 - accuracy: 0.9356 - val_loss: 0.2465 - val_accuracy: 0.9218
# Epoch 34/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.1704 - accuracy: 0.9363 - val_loss: 0.2359 - val_accuracy: 0.9268
# Epoch 35/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1692 - accuracy: 0.9368 - val_loss: 0.2487 - val_accuracy: 0.9207
# Epoch 36/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1691 - accuracy: 0.9370 - val_loss: 0.2609 - val_accuracy: 0.9215
# Epoch 37/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1699 - accuracy: 0.9369 - val_loss: 0.2510 - val_accuracy: 0.9211
# Epoch 38/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.1703 - accuracy: 0.9361 - val_loss: 0.2659 - val_accuracy: 0.9167
# Epoch 39/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1695 - accuracy: 0.9366 - val_loss: 0.2552 - val_accuracy: 0.9212
# Epoch 40/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1690 - accuracy: 0.9376 - val_loss: 0.2580 - val_accuracy: 0.9256
# Epoch 41/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1660 - accuracy: 0.9380 - val_loss: 0.2786 - val_accuracy: 0.9103
# Epoch 42/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1681 - accuracy: 0.9374 - val_loss: 0.2729 - val_accuracy: 0.9195
# Epoch 43/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1640 - accuracy: 0.9388 - val_loss: 0.2599 - val_accuracy: 0.9199
# Epoch 44/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1654 - accuracy: 0.9383 - val_loss: 0.2694 - val_accuracy: 0.9183
# Epoch 45/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1647 - accuracy: 0.9382 - val_loss: 0.3036 - val_accuracy: 0.9120
# Epoch 46/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1642 - accuracy: 0.9383 - val_loss: 0.2577 - val_accuracy: 0.9155
# Epoch 47/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.1635 - accuracy: 0.9390 - val_loss: 0.2428 - val_accuracy: 0.9260
# Epoch 48/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1632 - accuracy: 0.9391 - val_loss: 0.2578 - val_accuracy: 0.9165
# Epoch 49/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1632 - accuracy: 0.9393 - val_loss: 0.2667 - val_accuracy: 0.9227
# Epoch 50/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1641 - accuracy: 0.9386 - val_loss: 0.2763 - val_accuracy: 0.9200
# Epoch 51/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1617 - accuracy: 0.9393 - val_loss: 0.2699 - val_accuracy: 0.9147
# Epoch 52/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1630 - accuracy: 0.9402 - val_loss: 0.2765 - val_accuracy: 0.9099
# Epoch 53/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1596 - accuracy: 0.9398 - val_loss: 0.2608 - val_accuracy: 0.9262
# Epoch 54/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1623 - accuracy: 0.9400 - val_loss: 0.2837 - val_accuracy: 0.9160
# Epoch 55/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1612 - accuracy: 0.9399 - val_loss: 0.2911 - val_accuracy: 0.9135
# Epoch 56/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.1600 - accuracy: 0.9405 - val_loss: 0.2864 - val_accuracy: 0.9128
# Epoch 57/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1614 - accuracy: 0.9396 - val_loss: 0.2918 - val_accuracy: 0.9132
# Epoch 58/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.1613 - accuracy: 0.9402 - val_loss: 0.2624 - val_accuracy: 0.9249
# Epoch 59/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.1595 - accuracy: 0.9405 - val_loss: 0.2758 - val_accuracy: 0.9166
# Epoch 60/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.1600 - accuracy: 0.9398 - val_loss: 0.2946 - val_accuracy: 0.9164
# Epoch 61/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1597 - accuracy: 0.9403 - val_loss: 0.2666 - val_accuracy: 0.9195
# Epoch 62/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1587 - accuracy: 0.9406 - val_loss: 0.2846 - val_accuracy: 0.9194
# Epoch 63/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.1613 - accuracy: 0.9404 - val_loss: 0.2886 - val_accuracy: 0.9089
# Epoch 64/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1588 - accuracy: 0.9410 - val_loss: 0.2680 - val_accuracy: 0.9197
# Epoch 65/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1596 - accuracy: 0.9406 - val_loss: 0.3014 - val_accuracy: 0.9140
# Epoch 66/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1598 - accuracy: 0.9410 - val_loss: 0.2829 - val_accuracy: 0.9166
# Epoch 67/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.1579 - accuracy: 0.9406 - val_loss: 0.2760 - val_accuracy: 0.9177
# Epoch 68/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1605 - accuracy: 0.9404 - val_loss: 0.2696 - val_accuracy: 0.9254
# Epoch 69/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1589 - accuracy: 0.9411 - val_loss: 0.2873 - val_accuracy: 0.9129
# Epoch 70/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1568 - accuracy: 0.9419 - val_loss: 0.2996 - val_accuracy: 0.9090
# Epoch 71/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1552 - accuracy: 0.9424 - val_loss: 0.2859 - val_accuracy: 0.9196
# Epoch 72/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1560 - accuracy: 0.9420 - val_loss: 0.2933 - val_accuracy: 0.9202
# Epoch 73/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.1585 - accuracy: 0.9411 - val_loss: 0.2896 - val_accuracy: 0.9136
# Epoch 74/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1593 - accuracy: 0.9411 - val_loss: 0.2680 - val_accuracy: 0.9269
# Epoch 75/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1590 - accuracy: 0.9406 - val_loss: 0.2824 - val_accuracy: 0.9155
# Epoch 76/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1546 - accuracy: 0.9422 - val_loss: 0.2912 - val_accuracy: 0.9248
# Epoch 77/100
# 4375/4375 [==============================] - 45s 10ms/step - loss: 0.1563 - accuracy: 0.9414 - val_loss: 0.2868 - val_accuracy: 0.9205
# Epoch 78/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1591 - accuracy: 0.9408 - val_loss: 0.2960 - val_accuracy: 0.9167
# Epoch 79/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1579 - accuracy: 0.9417 - val_loss: 0.2890 - val_accuracy: 0.9194
# Epoch 80/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1579 - accuracy: 0.9421 - val_loss: 0.2852 - val_accuracy: 0.9233
# Epoch 81/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1582 - accuracy: 0.9417 - val_loss: 0.2825 - val_accuracy: 0.9200
# Epoch 82/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1599 - accuracy: 0.9414 - val_loss: 0.2821 - val_accuracy: 0.9198
# Epoch 83/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1568 - accuracy: 0.9416 - val_loss: 0.3077 - val_accuracy: 0.9185
# Epoch 84/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1575 - accuracy: 0.9427 - val_loss: 0.2935 - val_accuracy: 0.9165
# Epoch 85/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1575 - accuracy: 0.9421 - val_loss: 0.2838 - val_accuracy: 0.9183
# Epoch 86/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1577 - accuracy: 0.9423 - val_loss: 0.2849 - val_accuracy: 0.9192
# Epoch 87/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1552 - accuracy: 0.9426 - val_loss: 0.2925 - val_accuracy: 0.9183
# Epoch 88/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1540 - accuracy: 0.9428 - val_loss: 0.2971 - val_accuracy: 0.9231
# Epoch 89/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1558 - accuracy: 0.9432 - val_loss: 0.2967 - val_accuracy: 0.9182
# Epoch 90/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1567 - accuracy: 0.9421 - val_loss: 0.3087 - val_accuracy: 0.9080
# Epoch 91/100
# 4375/4375 [==============================] - 42s 10ms/step - loss: 0.1555 - accuracy: 0.9425 - val_loss: 0.2794 - val_accuracy: 0.9245
# Epoch 92/100
# 4375/4375 [==============================] - 42s 10ms/step - loss: 0.1549 - accuracy: 0.9428 - val_loss: 0.3023 - val_accuracy: 0.9157
# Epoch 93/100
# 4375/4375 [==============================] - 42s 10ms/step - loss: 0.1546 - accuracy: 0.9424 - val_loss: 0.3053 - val_accuracy: 0.9161
# Epoch 94/100
# 4375/4375 [==============================] - 42s 10ms/step - loss: 0.1558 - accuracy: 0.9436 - val_loss: 0.2925 - val_accuracy: 0.9166
# Epoch 95/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1545 - accuracy: 0.9429 - val_loss: 0.3080 - val_accuracy: 0.9155
# Epoch 96/100
# 4375/4375 [==============================] - 42s 10ms/step - loss: 0.1561 - accuracy: 0.9424 - val_loss: 0.3154 - val_accuracy: 0.9114
# Epoch 97/100
# 4375/4375 [==============================] - 42s 10ms/step - loss: 0.1564 - accuracy: 0.9426 - val_loss: 0.2871 - val_accuracy: 0.9136
# Epoch 98/100
# 4375/4375 [==============================] - 42s 10ms/step - loss: 0.1522 - accuracy: 0.9437 - val_loss: 0.3103 - val_accuracy: 0.9138
# Epoch 99/100
# 4375/4375 [==============================] - 43s 10ms/step - loss: 0.1541 - accuracy: 0.9434 - val_loss: 0.3076 - val_accuracy: 0.9197
# Epoch 100/100
# 4375/4375 [==============================] - 44s 10ms/step - loss: 0.1553 - accuracy: 0.9432 - val_loss: 0.2975 - val_accuracy: 0.9168

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training Accuracy vs Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training Loss vs Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Recognition and Post-Processing
# 1. The sort contours function is used to get the correct order of individual characters for correct output extraction. In this case for extracting a single word, a left to right sorting of individual characters is needed.
# 2. The get letters function fetches the list of letters and get word function gets the individual word.

# %%
def sort_contours(cnts, method="left-to-right"):
    reverse = False
    i = 0
    if method == "right-to-left" or method == "bottom-to-top":
        reverse = True
    if method == "top-to-bottom" or method == "bottom-to-top":
        i = 1
    boundingBoxes = [cv2.boundingRect(c) for c in cnts]
    (cnts, boundingBoxes) = zip(*sorted(zip(cnts, boundingBoxes),
    key=lambda b:b[1][i], reverse=reverse))
    # return the list of sorted contours and bounding boxes
    return (cnts, boundingBoxes)

# %%
def get_letters(img):
    letters = []
    image = cv2.imread(img)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ret,thresh1 = cv2.threshold(gray ,127,255,cv2.THRESH_BINARY_INV)
    dilated = cv2.dilate(thresh1, None, iterations=2)

    cnts = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    cnts = sort_contours(cnts, method="left-to-right")[0]
    # loop over the contours
    for c in cnts:
        if cv2.contourArea(c) > 10:
            (x, y, w, h) = cv2.boundingRect(c)
            cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
        roi = gray[y:y + h, x:x + w]
        thresh = cv2.threshold(roi, 0, 255,cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]
        thresh = cv2.resize(thresh, (32, 32), interpolation = cv2.INTER_CUBIC)
        thresh = thresh.astype("float32") / 255.0
        thresh = np.expand_dims(thresh, axis=-1)
        thresh = thresh.reshape(1,32,32,1)
        ypred = model.predict(thresh)
        ypred = LB.inverse_transform(ypred)
        [x] = ypred
        letters.append(x)
    return letters, image

#plt.imshow(image)

# %%
def get_word(letter):
    word = "".join(letter)
    return word

# %%
letter,image = get_letters("/home/dung/Desktop/offline-handwritten-text-ocr/dataset/train_v2/train/TRAIN_00003.jpg")
word = get_word(letter)
print(word)
plt.imshow(image)
# Out:
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# BTNE5

# %%
letter,image = get_letters("/home/dung/Desktop/offline-handwritten-text-ocr/dataset/train_v2/train/TRAIN_00023.jpg")
word = get_word(letter)
print(word)
plt.imshow(image)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# LIL0U

# %%
letter,image = get_letters("/home/dung/Desktop/offline-handwritten-text-ocr/dataset/train_v2/train/TRAIN_00030.jpg")
word = get_word(letter)
print(word)
plt.imshow(image)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 3AFFELX

# %%
letter,image = get_letters("/home/dung/Desktop/offline-handwritten-text-ocr/dataset/validation_v2/validation/VALIDATION_0005.jpg")
word = get_word(letter)
print(word)
plt.imshow(image)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# RUPP

# %%
letter,image = get_letters("/home/dung/Desktop/offline-handwritten-text-ocr/dataset/test_v2/test/TEST_0007.jpg")
word = get_word(letter)
print(word)
plt.imshow(image)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# VA1ENTINC
